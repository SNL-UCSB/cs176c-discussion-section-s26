# %% [markdown]
# # Discussion Section Week 1 - 4/3/26
# ## Wireshark Refresher Lab
# ###  **Goal**: Refresh yourself with using Wireshark to analyze packet captures

# %% [markdown]
# #### Before you Start Download these Files
# Make sure to download these 2 pcaps to reference during this lab.
# [speedtest_short_range.pcap](https://drive.google.com/file/d/1W_FyI7vvRDZegpIXgwNJSTuqZjTi6Tkz/view?usp=drive_link)
# [speedtest_long_range.pcap](https://drive.google.com/file/d/1uzl1WZ4ZvlTCZ8hQnKHiAnyW6sqlH-Mp/view?usp=drive_link)

# %% [markdown]
# ### How to dissect a packet?
# - Click on a row and you can see the raw packet bits in the bottom-right pane
# - In the bottom-left pane, you can see the headers and their values organized by different layers in the packet

# %% [markdown]
# ### How to compose filters?
# - We can construct flexible filters in wireshark using different headers
# - Examples of some filters
#     - "udp"
#         - The filter above shows packets with a UDP header
#     - "tcp.dstport == 80"
#         - Filter for outbound HTTP traffic
#     - "tcp.dstport == 80 and tcp.srcport == 4343"
#         - Filter for outbound HTTP traffic originating at port 4343
# - To construct filter with header fields, we need their wireshark names. The list of all protocols and their fields can be found at this [link](https://www.wireshark.org/docs/dfref/).
# - You can also know the field name by opening up a packet, and clicking the header field in that packet. The field name will be visible in the bottom-left corner.

# %% [markdown]
# ### Analyzing an Ookla Speed Test

# %% [markdown]
# This [speedtest](https://www.speedtest.net) was run on a laptop connected wirelessly to its local access point (AP) about 20 feet away from the AP. The speedtest was able to achieve a download speed of 250 Mbps. While the speedtest was running, wireshark was run on the same host producing [speedtest_short_range.pcap](https://drive.google.com/file/d/1W_FyI7vvRDZegpIXgwNJSTuqZjTi6Tkz/view?usp=drive_link). Download and open the packet capture with Wireshark and try to answer the following questions.
# 1. What is the IP of the client host running the speedtest?
# 2. What is the IP of the server(s) that are being used for the speedtest?
# 3. What is the MAC address of the client host?
# 4. What is MAC address of the next-hop gateway from the client host?
# 5. What does the MAC address of the next-hop gateway represent?
# 6. How many TCP packets are sent total between the client host and speedtest servers?
# 7. How many packets are retransmitted in the TCP connections during the speedtest?
# 8. What is the retransmission rate for the TCP packets between the client and server during the speedtest?
#
# Hints:
# [Wireshark TCP Display Filter Reference](https://www.wireshark.org/docs/dfref/t/tcp.html) (https://www.wireshark.org/docs/dfref/t/tcp.html)

# %% [markdown]
# *write your answers here*

# %% [markdown]
# ### Analyzing Ookla Speed Test (Long Range)

# %% [markdown]
# Now we will look at a second [speedtest](speedtest.net) that was run on the same laptop about 100 feet away from the AP. The speedtest was able to achieve a download speed of 25 Mbps. While the speedtest was running, wireshark was run on the same host producing [speedtest_long_range.pcap](https://drive.google.com/file/d/1uzl1WZ4ZvlTCZ8hQnKHiAnyW6sqlH-Mp/view?usp=drive_link). Download and open the packet capture with Wireshark and try to answer the following questions.
#
# 9. What is the IP of the server(s) that are being used for the speedtest?
# 10. How many TCP packets are sent total between the client host and speedtest servers?
# 11. How many packets are retransmitted in the TCP connections during the speedtest?
# 12. What is the retransmission rate for the TCP packets between the client and server during the speedtest?
# 13. What is the relationship between distance vs. signal strength and distance vs. loss over wireless?

# %% [markdown]
# *write your answers here*

# %% [markdown]
# ### Submission Instructions
#
# To receive full credit for this lab, you must submit your completed notebook as a **participation check** on [Gradescope](https://www.gradescope.com).
#
# **Steps to Submit:**
# 1. Make sure you have answered all questions (1–13) in the answer cells above
# 2. Save this notebook (`File` → `Save Notebook`)
# 3. Export the notebook as a PDF (`File` → `Save and Export Notebook As` → `PDF`)
# 4. Upload the PDF to the **participation1** assignment on Gradescope
#
# > **Due Date**: Make sure to submit by tonight (Friday 4/3) @ 11:59PM
